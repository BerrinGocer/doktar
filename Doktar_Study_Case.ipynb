# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

# %%
df = pd.read_csv (r'C:\Users\berrin.gocer\Desktop\HARVEST_TURKEY_R1_2021_GRAIN_v12.csv')
df.head()
# Out:
#    CityId CityNameTr  DistrictId DistrictNameTr PlaceName  GrainNoHarvestArea  \
# 0       1      ADANA          51        KARATAŞ     Adalı                 0.0
# 1       1      ADANA          51        KARATAŞ     Akdam                 0.0
# 2       1      ADANA          51        KARATAŞ     Bahçe                 0.0
# 3       1      ADANA          51        KARATAŞ    Bebeli                 0.0
# 4       1      ADANA          51        KARATAŞ    Beyköy                 0.0
#
#    GrainHarvestArea20210806  GrainHarvestArea20210808  \
# 0                  0.240369                  0.168601
# 1                  3.413119                  2.317323
# 2                  0.826600                  1.700446
# 3                  0.217250                  0.753051
# 4                  3.785405                  2.086331
#
#    GrainHarvestArea20210810  GrainHarvestArea20210811  ...  \
# 0                  0.280475                  5.227395  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21219 entries, 0 to 21218
# Columns: 130 entries, CityId to GrainHarvestArea20211127
# dtypes: float64(125), int64(2), object(3)
# memory usage: 21.0+ MB

# %%
df.columns
# Out:
# Index(['CityId', 'CityNameTr', 'DistrictId', 'DistrictNameTr', 'PlaceName',
#        'GrainNoHarvestArea', 'GrainHarvestArea20210806',
#        'GrainHarvestArea20210808', 'GrainHarvestArea20210810',
#        'GrainHarvestArea20210811',
#        ...
#        'GrainHarvestArea20211124', 'GrainHarvestArea20211126',
#        'GrainHarvestArea20211129', 'GrainHarvestArea20210801',
#        'GrainHarvestArea20210804', 'GrainHarvestArea20210803',
#        'GrainHarvestArea20210802', 'GrainHarvestArea20210807',
#        'GrainHarvestArea20210805', 'GrainHarvestArea20211127'],
#       dtype='object', length=130)

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of        CityId CityNameTr  DistrictId DistrictNameTr  PlaceName  \
# 0           1      ADANA          51        KARATAŞ      Adalı
# 1           1      ADANA          51        KARATAŞ      Akdam
# 2           1      ADANA          51        KARATAŞ      Bahçe
# 3           1      ADANA          51        KARATAŞ     Bebeli
# 4           1      ADANA          51        KARATAŞ     Beyköy
# ...       ...        ...         ...            ...        ...
# 21214      67  ZONGULDAK        1048        ÇAYCUMA   Yazıbaşı
# 21215      67  ZONGULDAK        1048        ÇAYCUMA    Yeniköy
# 21216      67  ZONGULDAK        1048        ÇAYCUMA  Yenipazar
# 21217      67  ZONGULDAK        1048        ÇAYCUMA   Yeşilköy
# 21218      67  ZONGULDAK        1048        ÇAYCUMA        NaN
#
#        GrainNoHarvestArea  GrainHarvestArea20210806  GrainHarvestArea20210808  \
# 0                     0.0                  0.240369                  0.168601
# ...

# %%
df.columns
# Out:
# Index(['CityId', 'CityNameTr', 'DistrictId', 'DistrictNameTr', 'PlaceName',
#        'GrainNoHarvestArea', 'GrainHarvestArea20210806',
#        'GrainHarvestArea20210808', 'GrainHarvestArea20210810',
#        'GrainHarvestArea20210811',
#        ...
#        'GrainHarvestArea20211124', 'GrainHarvestArea20211126',
#        'GrainHarvestArea20211129', 'GrainHarvestArea20210801',
#        'GrainHarvestArea20210804', 'GrainHarvestArea20210803',
#        'GrainHarvestArea20210802', 'GrainHarvestArea20210807',
#        'GrainHarvestArea20210805', 'GrainHarvestArea20211127'],
#       dtype='object', length=130)

# %%
list = ["CityId","CityNameTr","DistrictId","DistrictNameTr","PlaceName","GrainNoHarvestArea","GrainHarvestArea20210806",
         "GrainHarvestArea20210808","GrainHarvestArea20210810","GrainHarvestArea20210811",
         "GrainHarvestArea20210813","GrainHarvestArea20210815","GrainHarvestArea20210816","GrainHarvestArea20210817",
         "GrainHarvestArea20210818","GrainHarvestArea20210820","GrainHarvestArea20210821","GrainHarvestArea20210822",
         "GrainHarvestArea20210823","GrainHarvestArea20210825","GrainHarvestArea20210826","GrainHarvestArea20210827",
         "GrainHarvestArea20210828","GrainHarvestArea20210830","GrainHarvestArea20210831","GrainHarvestArea20210901","GrainHarvestArea20210902",
         "GrainHarvestArea20210904","GrainHarvestArea20210905","GrainHarvestArea20210906","GrainHarvestArea20210907","GrainHarvestArea20210909",
         "GrainHarvestArea20210910","GrainHarvestArea20210911","GrainHarvestArea20210912","GrainHarvestArea20210914","GrainHarvestArea20210915",
         "GrainHarvestArea20210917","GrainHarvestArea20210919","GrainHarvestArea20210920","GrainHarvestArea20210922","GrainHarvestArea20210924",
         "GrainHarvestArea20210925","GrainHarvestArea20210926","GrainHarvestArea20210927","GrainHarvestArea20210929","GrainHarvestArea20210930",
         "GrainHarvestArea20211001","GrainHarvestArea20211002","GrainHarvestArea20211004","GrainHarvestArea20211005","GrainHarvestArea20211006",
         "GrainHarvestArea20211007","GrainHarvestArea20211009","GrainHarvestArea20211010","GrainHarvestArea20211011","GrainHarvestArea20211012",
         "GrainHarvestArea20211014","GrainHarvestArea20211015","GrainHarvestArea20211016","GrainHarvestArea20211017","GrainHarvestArea20211019",
         "GrainHarvestArea20211020","GrainHarvestArea20211021","GrainHarvestArea20211022","GrainHarvestArea20211024","GrainHarvestArea20211025",
         "GrainHarvestArea20211026","GrainHarvestArea20211027","GrainHarvestArea20211029","GrainHarvestArea20211030","GrainHarvestArea20211031",
         "GrainHarvestArea20211101","GrainHarvestArea20211103","GrainHarvestArea20211104","GrainHarvestArea20211105","GrainHarvestArea20211106",
         "GrainHarvestArea20211108","GrainHarvestArea20211110","GrainHarvestArea20211111","GrainHarvestArea20211113","GrainHarvestArea20211114",
         "GrainHarvestArea20211115","GrainHarvestArea20211116","GrainHarvestArea20211118","GrainHarvestArea20211120","GrainHarvestArea20211121",
         "GrainHarvestArea20211123","GrainHarvestArea20211125","GrainHarvestArea20211128","GrainHarvestArea20211130","GrainHarvestArea20211231",
         "GrainHarvestArea20220101","GrainHarvestArea20210812","GrainHarvestArea20210819","GrainHarvestArea20210824","GrainHarvestArea20210829",
         "GrainHarvestArea20210903","GrainHarvestArea20210908","GrainHarvestArea20210913","GrainHarvestArea20210918","GrainHarvestArea20211003",
         "GrainHarvestArea20211013","GrainHarvestArea20211018","GrainHarvestArea20211023","GrainHarvestArea20211102","GrainHarvestArea20211107",
         "GrainHarvestArea20211112","GrainHarvestArea20210809","GrainHarvestArea20210814","GrainHarvestArea20210916","GrainHarvestArea20210921",
         "GrainHarvestArea20210923","GrainHarvestArea20210928","GrainHarvestArea20211008","GrainHarvestArea20211028","GrainHarvestArea20211109",
         "GrainHarvestArea20211117","GrainHarvestArea20211119","GrainHarvestArea20211122","GrainHarvestArea20211124","GrainHarvestArea20211126",
         "GrainHarvestArea20211129","GrainHarvestArea20210801","GrainHarvestArea20210804","GrainHarvestArea20210803","GrainHarvestArea20210802",
         "GrainHarvestArea20210807","GrainHarvestArea20210805","GrainHarvestArea20211127"]
print(len(list))
# Out:
# 130

# %%
list.sort()

# %%
print(list)
# Out:
# ['CityId', 'CityNameTr', 'DistrictId', 'DistrictNameTr', 'GrainHarvestArea20210801', 'GrainHarvestArea20210802', 'GrainHarvestArea20210803', 'GrainHarvestArea20210804', 'GrainHarvestArea20210805', 'GrainHarvestArea20210806', 'GrainHarvestArea20210807', 'GrainHarvestArea20210808', 'GrainHarvestArea20210809', 'GrainHarvestArea20210810', 'GrainHarvestArea20210811', 'GrainHarvestArea20210812', 'GrainHarvestArea20210813', 'GrainHarvestArea20210814', 'GrainHarvestArea20210815', 'GrainHarvestArea20210816', 'GrainHarvestArea20210817', 'GrainHarvestArea20210818', 'GrainHarvestArea20210819', 'GrainHarvestArea20210820', 'GrainHarvestArea20210821', 'GrainHarvestArea20210822', 'GrainHarvestArea20210823', 'GrainHarvestArea20210824', 'GrainHarvestArea20210825', 'GrainHarvestArea20210826', 'GrainHarvestArea20210827', 'GrainHarvestArea20210828', 'GrainHarvestArea20210829', 'GrainHarvestArea20210830', 'GrainHarvestArea20210831', 'GrainHarvestArea20210901', 'GrainHarvestArea20210902', 'GrainHarvestArea
# ...

# %%
listt = ['CityId', 'CityNameTr', 'DistrictId', 'DistrictNameTr', 'PlaceName','GrainNoHarvestArea', 
         'GrainHarvestArea20210801', 'GrainHarvestArea20210802', 'GrainHarvestArea20210803', 'GrainHarvestArea20210804', 
         'GrainHarvestArea20210805', 'GrainHarvestArea20210806', 'GrainHarvestArea20210807', 'GrainHarvestArea20210808', 
         'GrainHarvestArea20210809', 'GrainHarvestArea20210810', 'GrainHarvestArea20210811', 'GrainHarvestArea20210812', 
         'GrainHarvestArea20210813', 'GrainHarvestArea20210814', 'GrainHarvestArea20210815', 'GrainHarvestArea20210816', 
         'GrainHarvestArea20210817', 'GrainHarvestArea20210818', 'GrainHarvestArea20210819', 'GrainHarvestArea20210820', 
         'GrainHarvestArea20210821', 'GrainHarvestArea20210822', 'GrainHarvestArea20210823', 'GrainHarvestArea20210824', 
         'GrainHarvestArea20210825', 'GrainHarvestArea20210826', 'GrainHarvestArea20210827', 'GrainHarvestArea20210828', 
         'GrainHarvestArea20210829', 'GrainHarvestArea20210830', 'GrainHarvestArea20210831', 'GrainHarvestArea20210901', 
         'GrainHarvestArea20210902', 'GrainHarvestArea20210903', 'GrainHarvestArea20210904', 'GrainHarvestArea20210905', 
         'GrainHarvestArea20210906', 'GrainHarvestArea20210907', 'GrainHarvestArea20210908', 'GrainHarvestArea20210909', 
         'GrainHarvestArea20210910', 'GrainHarvestArea20210911', 'GrainHarvestArea20210912', 'GrainHarvestArea20210913', 
         'GrainHarvestArea20210914', 'GrainHarvestArea20210915', 'GrainHarvestArea20210916', 'GrainHarvestArea20210917', 
         'GrainHarvestArea20210918', 'GrainHarvestArea20210919','GrainHarvestArea20210920', 'GrainHarvestArea20210921', 
         'GrainHarvestArea20210922', 'GrainHarvestArea20210923', 'GrainHarvestArea20210924', 'GrainHarvestArea20210925', 
         'GrainHarvestArea20210926', 'GrainHarvestArea20210927', 'GrainHarvestArea20210928', 'GrainHarvestArea20210929', 
         'GrainHarvestArea20210930', 'GrainHarvestArea20211001', 'GrainHarvestArea20211002', 'GrainHarvestArea20211003', 
         'GrainHarvestArea20211004', 'GrainHarvestArea20211005', 'GrainHarvestArea20211006', 'GrainHarvestArea20211007', 
         'GrainHarvestArea20211008', 'GrainHarvestArea20211009', 'GrainHarvestArea20211010', 'GrainHarvestArea20211011', 
         'GrainHarvestArea20211012', 'GrainHarvestArea20211013', 'GrainHarvestArea20211014', 'GrainHarvestArea20211015', 
         'GrainHarvestArea20211016', 'GrainHarvestArea20211017', 'GrainHarvestArea20211018', 'GrainHarvestArea20211019', 
         'GrainHarvestArea20211020', 'GrainHarvestArea20211021', 'GrainHarvestArea20211022', 'GrainHarvestArea20211023', 
         'GrainHarvestArea20211024', 'GrainHarvestArea20211025', 'GrainHarvestArea20211026', 'GrainHarvestArea20211027', 
         'GrainHarvestArea20211028', 'GrainHarvestArea20211029', 'GrainHarvestArea20211030', 'GrainHarvestArea20211031', 
         'GrainHarvestArea20211101', 'GrainHarvestArea20211102', 'GrainHarvestArea20211103', 'GrainHarvestArea20211104', 
         'GrainHarvestArea20211105', 'GrainHarvestArea20211106', 'GrainHarvestArea20211107', 'GrainHarvestArea20211108', 
         'GrainHarvestArea20211109', 'GrainHarvestArea20211110', 'GrainHarvestArea20211111', 'GrainHarvestArea20211112', 
         'GrainHarvestArea20211113', 'GrainHarvestArea20211114', 'GrainHarvestArea20211115', 'GrainHarvestArea20211116', 
         'GrainHarvestArea20211117', 'GrainHarvestArea20211118', 'GrainHarvestArea20211119', 'GrainHarvestArea20211120', 
         'GrainHarvestArea20211121', 'GrainHarvestArea20211122', 'GrainHarvestArea20211123', 'GrainHarvestArea20211124', 
         'GrainHarvestArea20211125', 'GrainHarvestArea20211126', 'GrainHarvestArea20211127', 'GrainHarvestArea20211128', 
         'GrainHarvestArea20211129', 'GrainHarvestArea20211130', 'GrainHarvestArea20211231', 'GrainHarvestArea20220101']

# %%
len(listt)
# Out:
# 130

# %%
df1=df.loc[:,listt]

# %%
df1.head(5)
# Out:
#    CityId CityNameTr  DistrictId DistrictNameTr PlaceName  GrainNoHarvestArea  \
# 0       1      ADANA          51        KARATAŞ     Adalı                 0.0
# 1       1      ADANA          51        KARATAŞ     Akdam                 0.0
# 2       1      ADANA          51        KARATAŞ     Bahçe                 0.0
# 3       1      ADANA          51        KARATAŞ    Bebeli                 0.0
# 4       1      ADANA          51        KARATAŞ    Beyköy                 0.0
#
#    GrainHarvestArea20210801  GrainHarvestArea20210802  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    GrainHarvestArea20210803  GrainHarvestArea20210804  ...  \
# 0                       NaN                       NaN  ...
# ...

# %%
list_27_09_21 = ['CityId', 'CityNameTr', 'DistrictId', 'DistrictNameTr', 'PlaceName','GrainNoHarvestArea', 
         'GrainHarvestArea20210801', 'GrainHarvestArea20210802', 'GrainHarvestArea20210803', 'GrainHarvestArea20210804', 
         'GrainHarvestArea20210805', 'GrainHarvestArea20210806', 'GrainHarvestArea20210807', 'GrainHarvestArea20210808', 
         'GrainHarvestArea20210809', 'GrainHarvestArea20210810', 'GrainHarvestArea20210811', 'GrainHarvestArea20210812', 
         'GrainHarvestArea20210813', 'GrainHarvestArea20210814', 'GrainHarvestArea20210815', 'GrainHarvestArea20210816', 
         'GrainHarvestArea20210817', 'GrainHarvestArea20210818', 'GrainHarvestArea20210819', 'GrainHarvestArea20210820', 
         'GrainHarvestArea20210821', 'GrainHarvestArea20210822', 'GrainHarvestArea20210823', 'GrainHarvestArea20210824', 
         'GrainHarvestArea20210825', 'GrainHarvestArea20210826', 'GrainHarvestArea20210827', 'GrainHarvestArea20210828', 
         'GrainHarvestArea20210829', 'GrainHarvestArea20210830', 'GrainHarvestArea20210831', 'GrainHarvestArea20210901', 
         'GrainHarvestArea20210902', 'GrainHarvestArea20210903', 'GrainHarvestArea20210904', 'GrainHarvestArea20210905', 
         'GrainHarvestArea20210906', 'GrainHarvestArea20210907', 'GrainHarvestArea20210908', 'GrainHarvestArea20210909', 
         'GrainHarvestArea20210910', 'GrainHarvestArea20210911', 'GrainHarvestArea20210912', 'GrainHarvestArea20210913', 
         'GrainHarvestArea20210914', 'GrainHarvestArea20210915', 'GrainHarvestArea20210916', 'GrainHarvestArea20210917', 
         'GrainHarvestArea20210918', 'GrainHarvestArea20210919','GrainHarvestArea20210920', 'GrainHarvestArea20210921', 
         'GrainHarvestArea20210922', 'GrainHarvestArea20210923', 'GrainHarvestArea20210924', 'GrainHarvestArea20210925', 
         'GrainHarvestArea20210926', 'GrainHarvestArea20210927']
print(len(list_27_09_21))
# Out:
# 64

# %%
list_10_10_21= ['CityId', 'CityNameTr', 'DistrictId', 'DistrictNameTr', 'PlaceName','GrainNoHarvestArea', 
         'GrainHarvestArea20210801', 'GrainHarvestArea20210802', 'GrainHarvestArea20210803', 'GrainHarvestArea20210804', 
         'GrainHarvestArea20210805', 'GrainHarvestArea20210806', 'GrainHarvestArea20210807', 'GrainHarvestArea20210808', 
         'GrainHarvestArea20210809', 'GrainHarvestArea20210810', 'GrainHarvestArea20210811', 'GrainHarvestArea20210812', 
         'GrainHarvestArea20210813', 'GrainHarvestArea20210814', 'GrainHarvestArea20210815', 'GrainHarvestArea20210816', 
         'GrainHarvestArea20210817', 'GrainHarvestArea20210818', 'GrainHarvestArea20210819', 'GrainHarvestArea20210820', 
         'GrainHarvestArea20210821', 'GrainHarvestArea20210822', 'GrainHarvestArea20210823', 'GrainHarvestArea20210824', 
         'GrainHarvestArea20210825', 'GrainHarvestArea20210826', 'GrainHarvestArea20210827', 'GrainHarvestArea20210828', 
         'GrainHarvestArea20210829', 'GrainHarvestArea20210830', 'GrainHarvestArea20210831', 'GrainHarvestArea20210901', 
         'GrainHarvestArea20210902', 'GrainHarvestArea20210903', 'GrainHarvestArea20210904', 'GrainHarvestArea20210905', 
         'GrainHarvestArea20210906', 'GrainHarvestArea20210907', 'GrainHarvestArea20210908', 'GrainHarvestArea20210909', 
         'GrainHarvestArea20210910', 'GrainHarvestArea20210911', 'GrainHarvestArea20210912', 'GrainHarvestArea20210913', 
         'GrainHarvestArea20210914', 'GrainHarvestArea20210915', 'GrainHarvestArea20210916', 'GrainHarvestArea20210917', 
         'GrainHarvestArea20210918', 'GrainHarvestArea20210919','GrainHarvestArea20210920', 'GrainHarvestArea20210921', 
         'GrainHarvestArea20210922', 'GrainHarvestArea20210923', 'GrainHarvestArea20210924', 'GrainHarvestArea20210925', 
         'GrainHarvestArea20210926', 'GrainHarvestArea20210927', 'GrainHarvestArea20210928', 'GrainHarvestArea20210929', 
         'GrainHarvestArea20210930', 'GrainHarvestArea20211001', 'GrainHarvestArea20211002', 'GrainHarvestArea20211003', 
         'GrainHarvestArea20211004', 'GrainHarvestArea20211005', 'GrainHarvestArea20211006', 'GrainHarvestArea20211007', 
         'GrainHarvestArea20211008', 'GrainHarvestArea20211009', 'GrainHarvestArea20211010']
print(len(list_10_10_21))
# Out:
# 77

# %%
list_17_10_21 = ['CityId', 'CityNameTr', 'DistrictId', 'DistrictNameTr', 'PlaceName','GrainNoHarvestArea', 
         'GrainHarvestArea20210801', 'GrainHarvestArea20210802', 'GrainHarvestArea20210803', 'GrainHarvestArea20210804', 
         'GrainHarvestArea20210805', 'GrainHarvestArea20210806', 'GrainHarvestArea20210807', 'GrainHarvestArea20210808', 
         'GrainHarvestArea20210809', 'GrainHarvestArea20210810', 'GrainHarvestArea20210811', 'GrainHarvestArea20210812', 
         'GrainHarvestArea20210813', 'GrainHarvestArea20210814', 'GrainHarvestArea20210815', 'GrainHarvestArea20210816', 
         'GrainHarvestArea20210817', 'GrainHarvestArea20210818', 'GrainHarvestArea20210819', 'GrainHarvestArea20210820', 
         'GrainHarvestArea20210821', 'GrainHarvestArea20210822', 'GrainHarvestArea20210823', 'GrainHarvestArea20210824', 
         'GrainHarvestArea20210825', 'GrainHarvestArea20210826', 'GrainHarvestArea20210827', 'GrainHarvestArea20210828', 
         'GrainHarvestArea20210829', 'GrainHarvestArea20210830', 'GrainHarvestArea20210831', 'GrainHarvestArea20210901', 
         'GrainHarvestArea20210902', 'GrainHarvestArea20210903', 'GrainHarvestArea20210904', 'GrainHarvestArea20210905', 
         'GrainHarvestArea20210906', 'GrainHarvestArea20210907', 'GrainHarvestArea20210908', 'GrainHarvestArea20210909', 
         'GrainHarvestArea20210910', 'GrainHarvestArea20210911', 'GrainHarvestArea20210912', 'GrainHarvestArea20210913', 
         'GrainHarvestArea20210914', 'GrainHarvestArea20210915', 'GrainHarvestArea20210916', 'GrainHarvestArea20210917', 
         'GrainHarvestArea20210918', 'GrainHarvestArea20210919','GrainHarvestArea20210920', 'GrainHarvestArea20210921', 
         'GrainHarvestArea20210922', 'GrainHarvestArea20210923', 'GrainHarvestArea20210924', 'GrainHarvestArea20210925', 
         'GrainHarvestArea20210926', 'GrainHarvestArea20210927', 'GrainHarvestArea20210928', 'GrainHarvestArea20210929', 
         'GrainHarvestArea20210930', 'GrainHarvestArea20211001', 'GrainHarvestArea20211002', 'GrainHarvestArea20211003', 
         'GrainHarvestArea20211004', 'GrainHarvestArea20211005', 'GrainHarvestArea20211006', 'GrainHarvestArea20211007', 
         'GrainHarvestArea20211008', 'GrainHarvestArea20211009', 'GrainHarvestArea20211010', 'GrainHarvestArea20211011', 
         'GrainHarvestArea20211012', 'GrainHarvestArea20211013', 'GrainHarvestArea20211014', 'GrainHarvestArea20211015', 
         'GrainHarvestArea20211016', 'GrainHarvestArea20211017']
print(len(list_17_10_21))
# Out:
# 84

# %%
list_24_10_21 = ['CityId', 'CityNameTr', 'DistrictId', 'DistrictNameTr', 'PlaceName','GrainNoHarvestArea', 
         'GrainHarvestArea20210801', 'GrainHarvestArea20210802', 'GrainHarvestArea20210803', 'GrainHarvestArea20210804', 
         'GrainHarvestArea20210805', 'GrainHarvestArea20210806', 'GrainHarvestArea20210807', 'GrainHarvestArea20210808', 
         'GrainHarvestArea20210809', 'GrainHarvestArea20210810', 'GrainHarvestArea20210811', 'GrainHarvestArea20210812', 
         'GrainHarvestArea20210813', 'GrainHarvestArea20210814', 'GrainHarvestArea20210815', 'GrainHarvestArea20210816', 
         'GrainHarvestArea20210817', 'GrainHarvestArea20210818', 'GrainHarvestArea20210819', 'GrainHarvestArea20210820', 
         'GrainHarvestArea20210821', 'GrainHarvestArea20210822', 'GrainHarvestArea20210823', 'GrainHarvestArea20210824', 
         'GrainHarvestArea20210825', 'GrainHarvestArea20210826', 'GrainHarvestArea20210827', 'GrainHarvestArea20210828', 
         'GrainHarvestArea20210829', 'GrainHarvestArea20210830', 'GrainHarvestArea20210831', 'GrainHarvestArea20210901', 
         'GrainHarvestArea20210902', 'GrainHarvestArea20210903', 'GrainHarvestArea20210904', 'GrainHarvestArea20210905', 
         'GrainHarvestArea20210906', 'GrainHarvestArea20210907', 'GrainHarvestArea20210908', 'GrainHarvestArea20210909', 
         'GrainHarvestArea20210910', 'GrainHarvestArea20210911', 'GrainHarvestArea20210912', 'GrainHarvestArea20210913', 
         'GrainHarvestArea20210914', 'GrainHarvestArea20210915', 'GrainHarvestArea20210916', 'GrainHarvestArea20210917', 
         'GrainHarvestArea20210918', 'GrainHarvestArea20210919','GrainHarvestArea20210920', 'GrainHarvestArea20210921', 
         'GrainHarvestArea20210922', 'GrainHarvestArea20210923', 'GrainHarvestArea20210924', 'GrainHarvestArea20210925', 
         'GrainHarvestArea20210926', 'GrainHarvestArea20210927', 'GrainHarvestArea20210928', 'GrainHarvestArea20210929', 
         'GrainHarvestArea20210930', 'GrainHarvestArea20211001', 'GrainHarvestArea20211002', 'GrainHarvestArea20211003', 
         'GrainHarvestArea20211004', 'GrainHarvestArea20211005', 'GrainHarvestArea20211006', 'GrainHarvestArea20211007', 
         'GrainHarvestArea20211008', 'GrainHarvestArea20211009', 'GrainHarvestArea20211010', 'GrainHarvestArea20211011', 
         'GrainHarvestArea20211012', 'GrainHarvestArea20211013', 'GrainHarvestArea20211014', 'GrainHarvestArea20211015', 
         'GrainHarvestArea20211016', 'GrainHarvestArea20211017', 'GrainHarvestArea20211018', 'GrainHarvestArea20211019', 
         'GrainHarvestArea20211020', 'GrainHarvestArea20211021', 'GrainHarvestArea20211022', 'GrainHarvestArea20211023', 
         'GrainHarvestArea20211024']
print(len(list_24_10_21))
# Out:
# 91

# %%
list_30_10_21 =['CityId', 'CityNameTr', 'DistrictId', 'DistrictNameTr', 'PlaceName','GrainNoHarvestArea', 
         'GrainHarvestArea20210801', 'GrainHarvestArea20210802', 'GrainHarvestArea20210803', 'GrainHarvestArea20210804', 
         'GrainHarvestArea20210805', 'GrainHarvestArea20210806', 'GrainHarvestArea20210807', 'GrainHarvestArea20210808', 
         'GrainHarvestArea20210809', 'GrainHarvestArea20210810', 'GrainHarvestArea20210811', 'GrainHarvestArea20210812', 
         'GrainHarvestArea20210813', 'GrainHarvestArea20210814', 'GrainHarvestArea20210815', 'GrainHarvestArea20210816', 
         'GrainHarvestArea20210817', 'GrainHarvestArea20210818', 'GrainHarvestArea20210819', 'GrainHarvestArea20210820', 
         'GrainHarvestArea20210821', 'GrainHarvestArea20210822', 'GrainHarvestArea20210823', 'GrainHarvestArea20210824', 
         'GrainHarvestArea20210825', 'GrainHarvestArea20210826', 'GrainHarvestArea20210827', 'GrainHarvestArea20210828', 
         'GrainHarvestArea20210829', 'GrainHarvestArea20210830', 'GrainHarvestArea20210831', 'GrainHarvestArea20210901', 
         'GrainHarvestArea20210902', 'GrainHarvestArea20210903', 'GrainHarvestArea20210904', 'GrainHarvestArea20210905', 
         'GrainHarvestArea20210906', 'GrainHarvestArea20210907', 'GrainHarvestArea20210908', 'GrainHarvestArea20210909', 
         'GrainHarvestArea20210910', 'GrainHarvestArea20210911', 'GrainHarvestArea20210912', 'GrainHarvestArea20210913', 
         'GrainHarvestArea20210914', 'GrainHarvestArea20210915', 'GrainHarvestArea20210916', 'GrainHarvestArea20210917', 
         'GrainHarvestArea20210918', 'GrainHarvestArea20210919','GrainHarvestArea20210920', 'GrainHarvestArea20210921', 
         'GrainHarvestArea20210922', 'GrainHarvestArea20210923', 'GrainHarvestArea20210924', 'GrainHarvestArea20210925', 
         'GrainHarvestArea20210926', 'GrainHarvestArea20210927', 'GrainHarvestArea20210928', 'GrainHarvestArea20210929', 
         'GrainHarvestArea20210930', 'GrainHarvestArea20211001', 'GrainHarvestArea20211002', 'GrainHarvestArea20211003', 
         'GrainHarvestArea20211004', 'GrainHarvestArea20211005', 'GrainHarvestArea20211006', 'GrainHarvestArea20211007', 
         'GrainHarvestArea20211008', 'GrainHarvestArea20211009', 'GrainHarvestArea20211010', 'GrainHarvestArea20211011', 
         'GrainHarvestArea20211012', 'GrainHarvestArea20211013', 'GrainHarvestArea20211014', 'GrainHarvestArea20211015', 
         'GrainHarvestArea20211016', 'GrainHarvestArea20211017', 'GrainHarvestArea20211018', 'GrainHarvestArea20211019', 
         'GrainHarvestArea20211020', 'GrainHarvestArea20211021', 'GrainHarvestArea20211022', 'GrainHarvestArea20211023', 
         'GrainHarvestArea20211024', 'GrainHarvestArea20211025', 'GrainHarvestArea20211026', 'GrainHarvestArea20211027', 
         'GrainHarvestArea20211028', 'GrainHarvestArea20211029', 'GrainHarvestArea20211030']
print(len(list_30_10_21))
# Out:
# 97

# %%
list_07_11_21 =['CityId', 'CityNameTr', 'DistrictId', 'DistrictNameTr', 'PlaceName','GrainNoHarvestArea', 
         'GrainHarvestArea20210801', 'GrainHarvestArea20210802', 'GrainHarvestArea20210803', 'GrainHarvestArea20210804', 
         'GrainHarvestArea20210805', 'GrainHarvestArea20210806', 'GrainHarvestArea20210807', 'GrainHarvestArea20210808', 
         'GrainHarvestArea20210809', 'GrainHarvestArea20210810', 'GrainHarvestArea20210811', 'GrainHarvestArea20210812', 
         'GrainHarvestArea20210813', 'GrainHarvestArea20210814', 'GrainHarvestArea20210815', 'GrainHarvestArea20210816', 
         'GrainHarvestArea20210817', 'GrainHarvestArea20210818', 'GrainHarvestArea20210819', 'GrainHarvestArea20210820', 
         'GrainHarvestArea20210821', 'GrainHarvestArea20210822', 'GrainHarvestArea20210823', 'GrainHarvestArea20210824', 
         'GrainHarvestArea20210825', 'GrainHarvestArea20210826', 'GrainHarvestArea20210827', 'GrainHarvestArea20210828', 
         'GrainHarvestArea20210829', 'GrainHarvestArea20210830', 'GrainHarvestArea20210831', 'GrainHarvestArea20210901', 
         'GrainHarvestArea20210902', 'GrainHarvestArea20210903', 'GrainHarvestArea20210904', 'GrainHarvestArea20210905', 
         'GrainHarvestArea20210906', 'GrainHarvestArea20210907', 'GrainHarvestArea20210908', 'GrainHarvestArea20210909', 
         'GrainHarvestArea20210910', 'GrainHarvestArea20210911', 'GrainHarvestArea20210912', 'GrainHarvestArea20210913', 
         'GrainHarvestArea20210914', 'GrainHarvestArea20210915', 'GrainHarvestArea20210916', 'GrainHarvestArea20210917', 
         'GrainHarvestArea20210918', 'GrainHarvestArea20210919','GrainHarvestArea20210920', 'GrainHarvestArea20210921', 
         'GrainHarvestArea20210922', 'GrainHarvestArea20210923', 'GrainHarvestArea20210924', 'GrainHarvestArea20210925', 
         'GrainHarvestArea20210926', 'GrainHarvestArea20210927', 'GrainHarvestArea20210928', 'GrainHarvestArea20210929', 
         'GrainHarvestArea20210930', 'GrainHarvestArea20211001', 'GrainHarvestArea20211002', 'GrainHarvestArea20211003', 
         'GrainHarvestArea20211004', 'GrainHarvestArea20211005', 'GrainHarvestArea20211006', 'GrainHarvestArea20211007', 
         'GrainHarvestArea20211008', 'GrainHarvestArea20211009', 'GrainHarvestArea20211010', 'GrainHarvestArea20211011', 
         'GrainHarvestArea20211012', 'GrainHarvestArea20211013', 'GrainHarvestArea20211014', 'GrainHarvestArea20211015', 
         'GrainHarvestArea20211016', 'GrainHarvestArea20211017', 'GrainHarvestArea20211018', 'GrainHarvestArea20211019', 
         'GrainHarvestArea20211020', 'GrainHarvestArea20211021', 'GrainHarvestArea20211022', 'GrainHarvestArea20211023', 
         'GrainHarvestArea20211024', 'GrainHarvestArea20211025', 'GrainHarvestArea20211026', 'GrainHarvestArea20211027', 
         'GrainHarvestArea20211028', 'GrainHarvestArea20211029', 'GrainHarvestArea20211030', 'GrainHarvestArea20211031', 
         'GrainHarvestArea20211101', 'GrainHarvestArea20211102', 'GrainHarvestArea20211103', 'GrainHarvestArea20211104', 
         'GrainHarvestArea20211105', 'GrainHarvestArea20211106', 'GrainHarvestArea20211107']
print(len(list_07_11_21))
# Out:
# 105

# %%
list_14_11_21 = ['CityId', 'CityNameTr', 'DistrictId', 'DistrictNameTr', 'PlaceName','GrainNoHarvestArea', 
         'GrainHarvestArea20210801', 'GrainHarvestArea20210802', 'GrainHarvestArea20210803', 'GrainHarvestArea20210804', 
         'GrainHarvestArea20210805', 'GrainHarvestArea20210806', 'GrainHarvestArea20210807', 'GrainHarvestArea20210808', 
         'GrainHarvestArea20210809', 'GrainHarvestArea20210810', 'GrainHarvestArea20210811', 'GrainHarvestArea20210812', 
         'GrainHarvestArea20210813', 'GrainHarvestArea20210814', 'GrainHarvestArea20210815', 'GrainHarvestArea20210816', 
         'GrainHarvestArea20210817', 'GrainHarvestArea20210818', 'GrainHarvestArea20210819', 'GrainHarvestArea20210820', 
         'GrainHarvestArea20210821', 'GrainHarvestArea20210822', 'GrainHarvestArea20210823', 'GrainHarvestArea20210824', 
         'GrainHarvestArea20210825', 'GrainHarvestArea20210826', 'GrainHarvestArea20210827', 'GrainHarvestArea20210828', 
         'GrainHarvestArea20210829', 'GrainHarvestArea20210830', 'GrainHarvestArea20210831', 'GrainHarvestArea20210901', 
         'GrainHarvestArea20210902', 'GrainHarvestArea20210903', 'GrainHarvestArea20210904', 'GrainHarvestArea20210905', 
         'GrainHarvestArea20210906', 'GrainHarvestArea20210907', 'GrainHarvestArea20210908', 'GrainHarvestArea20210909', 
         'GrainHarvestArea20210910', 'GrainHarvestArea20210911', 'GrainHarvestArea20210912', 'GrainHarvestArea20210913', 
         'GrainHarvestArea20210914', 'GrainHarvestArea20210915', 'GrainHarvestArea20210916', 'GrainHarvestArea20210917', 
         'GrainHarvestArea20210918', 'GrainHarvestArea20210919','GrainHarvestArea20210920', 'GrainHarvestArea20210921', 
         'GrainHarvestArea20210922', 'GrainHarvestArea20210923', 'GrainHarvestArea20210924', 'GrainHarvestArea20210925', 
         'GrainHarvestArea20210926', 'GrainHarvestArea20210927', 'GrainHarvestArea20210928', 'GrainHarvestArea20210929', 
         'GrainHarvestArea20210930', 'GrainHarvestArea20211001', 'GrainHarvestArea20211002', 'GrainHarvestArea20211003', 
         'GrainHarvestArea20211004', 'GrainHarvestArea20211005', 'GrainHarvestArea20211006', 'GrainHarvestArea20211007', 
         'GrainHarvestArea20211008', 'GrainHarvestArea20211009', 'GrainHarvestArea20211010', 'GrainHarvestArea20211011', 
         'GrainHarvestArea20211012', 'GrainHarvestArea20211013', 'GrainHarvestArea20211014', 'GrainHarvestArea20211015', 
         'GrainHarvestArea20211016', 'GrainHarvestArea20211017', 'GrainHarvestArea20211018', 'GrainHarvestArea20211019', 
         'GrainHarvestArea20211020', 'GrainHarvestArea20211021', 'GrainHarvestArea20211022', 'GrainHarvestArea20211023', 
         'GrainHarvestArea20211024', 'GrainHarvestArea20211025', 'GrainHarvestArea20211026', 'GrainHarvestArea20211027', 
         'GrainHarvestArea20211028', 'GrainHarvestArea20211029', 'GrainHarvestArea20211030', 'GrainHarvestArea20211031', 
         'GrainHarvestArea20211101', 'GrainHarvestArea20211102', 'GrainHarvestArea20211103', 'GrainHarvestArea20211104', 
         'GrainHarvestArea20211105', 'GrainHarvestArea20211106', 'GrainHarvestArea20211107', 'GrainHarvestArea20211108', 
         'GrainHarvestArea20211109', 'GrainHarvestArea20211110', 'GrainHarvestArea20211111', 'GrainHarvestArea20211112', 
         'GrainHarvestArea20211113', 'GrainHarvestArea20211114']
print(len(list_14_11_21))
# Out:
# 112

# %%
list_21_11_21 =['CityId', 'CityNameTr', 'DistrictId', 'DistrictNameTr', 'PlaceName','GrainNoHarvestArea', 
         'GrainHarvestArea20210801', 'GrainHarvestArea20210802', 'GrainHarvestArea20210803', 'GrainHarvestArea20210804', 
         'GrainHarvestArea20210805', 'GrainHarvestArea20210806', 'GrainHarvestArea20210807', 'GrainHarvestArea20210808', 
         'GrainHarvestArea20210809', 'GrainHarvestArea20210810', 'GrainHarvestArea20210811', 'GrainHarvestArea20210812', 
         'GrainHarvestArea20210813', 'GrainHarvestArea20210814', 'GrainHarvestArea20210815', 'GrainHarvestArea20210816', 
         'GrainHarvestArea20210817', 'GrainHarvestArea20210818', 'GrainHarvestArea20210819', 'GrainHarvestArea20210820', 
         'GrainHarvestArea20210821', 'GrainHarvestArea20210822', 'GrainHarvestArea20210823', 'GrainHarvestArea20210824', 
         'GrainHarvestArea20210825', 'GrainHarvestArea20210826', 'GrainHarvestArea20210827', 'GrainHarvestArea20210828', 
         'GrainHarvestArea20210829', 'GrainHarvestArea20210830', 'GrainHarvestArea20210831', 'GrainHarvestArea20210901', 
         'GrainHarvestArea20210902', 'GrainHarvestArea20210903', 'GrainHarvestArea20210904', 'GrainHarvestArea20210905', 
         'GrainHarvestArea20210906', 'GrainHarvestArea20210907', 'GrainHarvestArea20210908', 'GrainHarvestArea20210909', 
         'GrainHarvestArea20210910', 'GrainHarvestArea20210911', 'GrainHarvestArea20210912', 'GrainHarvestArea20210913', 
         'GrainHarvestArea20210914', 'GrainHarvestArea20210915', 'GrainHarvestArea20210916', 'GrainHarvestArea20210917', 
         'GrainHarvestArea20210918', 'GrainHarvestArea20210919','GrainHarvestArea20210920', 'GrainHarvestArea20210921', 
         'GrainHarvestArea20210922', 'GrainHarvestArea20210923', 'GrainHarvestArea20210924', 'GrainHarvestArea20210925', 
         'GrainHarvestArea20210926', 'GrainHarvestArea20210927', 'GrainHarvestArea20210928', 'GrainHarvestArea20210929', 
         'GrainHarvestArea20210930', 'GrainHarvestArea20211001', 'GrainHarvestArea20211002', 'GrainHarvestArea20211003', 
         'GrainHarvestArea20211004', 'GrainHarvestArea20211005', 'GrainHarvestArea20211006', 'GrainHarvestArea20211007', 
         'GrainHarvestArea20211008', 'GrainHarvestArea20211009', 'GrainHarvestArea20211010', 'GrainHarvestArea20211011', 
         'GrainHarvestArea20211012', 'GrainHarvestArea20211013', 'GrainHarvestArea20211014', 'GrainHarvestArea20211015', 
         'GrainHarvestArea20211016', 'GrainHarvestArea20211017', 'GrainHarvestArea20211018', 'GrainHarvestArea20211019', 
         'GrainHarvestArea20211020', 'GrainHarvestArea20211021', 'GrainHarvestArea20211022', 'GrainHarvestArea20211023', 
         'GrainHarvestArea20211024', 'GrainHarvestArea20211025', 'GrainHarvestArea20211026', 'GrainHarvestArea20211027', 
         'GrainHarvestArea20211028', 'GrainHarvestArea20211029', 'GrainHarvestArea20211030', 'GrainHarvestArea20211031', 
         'GrainHarvestArea20211101', 'GrainHarvestArea20211102', 'GrainHarvestArea20211103', 'GrainHarvestArea20211104', 
         'GrainHarvestArea20211105', 'GrainHarvestArea20211106', 'GrainHarvestArea20211107', 'GrainHarvestArea20211108', 
         'GrainHarvestArea20211109', 'GrainHarvestArea20211110', 'GrainHarvestArea20211111', 'GrainHarvestArea20211112', 
         'GrainHarvestArea20211113', 'GrainHarvestArea20211114', 'GrainHarvestArea20211115', 'GrainHarvestArea20211116', 
         'GrainHarvestArea20211117', 'GrainHarvestArea20211118', 'GrainHarvestArea20211119', 'GrainHarvestArea20211120', 
         'GrainHarvestArea20211121']
print(len(list_21_11_21))
# Out:
# 119

# %%
list_28_11_21 =['CityId', 'CityNameTr', 'DistrictId', 'DistrictNameTr', 'PlaceName','GrainNoHarvestArea', 
         'GrainHarvestArea20210801', 'GrainHarvestArea20210802', 'GrainHarvestArea20210803', 'GrainHarvestArea20210804', 
         'GrainHarvestArea20210805', 'GrainHarvestArea20210806', 'GrainHarvestArea20210807', 'GrainHarvestArea20210808', 
         'GrainHarvestArea20210809', 'GrainHarvestArea20210810', 'GrainHarvestArea20210811', 'GrainHarvestArea20210812', 
         'GrainHarvestArea20210813', 'GrainHarvestArea20210814', 'GrainHarvestArea20210815', 'GrainHarvestArea20210816', 
         'GrainHarvestArea20210817', 'GrainHarvestArea20210818', 'GrainHarvestArea20210819', 'GrainHarvestArea20210820', 
         'GrainHarvestArea20210821', 'GrainHarvestArea20210822', 'GrainHarvestArea20210823', 'GrainHarvestArea20210824', 
         'GrainHarvestArea20210825', 'GrainHarvestArea20210826', 'GrainHarvestArea20210827', 'GrainHarvestArea20210828', 
         'GrainHarvestArea20210829', 'GrainHarvestArea20210830', 'GrainHarvestArea20210831', 'GrainHarvestArea20210901', 
         'GrainHarvestArea20210902', 'GrainHarvestArea20210903', 'GrainHarvestArea20210904', 'GrainHarvestArea20210905', 
         'GrainHarvestArea20210906', 'GrainHarvestArea20210907', 'GrainHarvestArea20210908', 'GrainHarvestArea20210909', 
         'GrainHarvestArea20210910', 'GrainHarvestArea20210911', 'GrainHarvestArea20210912', 'GrainHarvestArea20210913', 
         'GrainHarvestArea20210914', 'GrainHarvestArea20210915', 'GrainHarvestArea20210916', 'GrainHarvestArea20210917', 
         'GrainHarvestArea20210918', 'GrainHarvestArea20210919','GrainHarvestArea20210920', 'GrainHarvestArea20210921', 
         'GrainHarvestArea20210922', 'GrainHarvestArea20210923', 'GrainHarvestArea20210924', 'GrainHarvestArea20210925', 
         'GrainHarvestArea20210926', 'GrainHarvestArea20210927', 'GrainHarvestArea20210928', 'GrainHarvestArea20210929', 
         'GrainHarvestArea20210930', 'GrainHarvestArea20211001', 'GrainHarvestArea20211002', 'GrainHarvestArea20211003', 
         'GrainHarvestArea20211004', 'GrainHarvestArea20211005', 'GrainHarvestArea20211006', 'GrainHarvestArea20211007', 
         'GrainHarvestArea20211008', 'GrainHarvestArea20211009', 'GrainHarvestArea20211010', 'GrainHarvestArea20211011', 
         'GrainHarvestArea20211012', 'GrainHarvestArea20211013', 'GrainHarvestArea20211014', 'GrainHarvestArea20211015', 
         'GrainHarvestArea20211016', 'GrainHarvestArea20211017', 'GrainHarvestArea20211018', 'GrainHarvestArea20211019', 
         'GrainHarvestArea20211020', 'GrainHarvestArea20211021', 'GrainHarvestArea20211022', 'GrainHarvestArea20211023', 
         'GrainHarvestArea20211024', 'GrainHarvestArea20211025', 'GrainHarvestArea20211026', 'GrainHarvestArea20211027', 
         'GrainHarvestArea20211028', 'GrainHarvestArea20211029', 'GrainHarvestArea20211030', 'GrainHarvestArea20211031', 
         'GrainHarvestArea20211101', 'GrainHarvestArea20211102', 'GrainHarvestArea20211103', 'GrainHarvestArea20211104', 
         'GrainHarvestArea20211105', 'GrainHarvestArea20211106', 'GrainHarvestArea20211107', 'GrainHarvestArea20211108', 
         'GrainHarvestArea20211109', 'GrainHarvestArea20211110', 'GrainHarvestArea20211111', 'GrainHarvestArea20211112', 
         'GrainHarvestArea20211113', 'GrainHarvestArea20211114', 'GrainHarvestArea20211115', 'GrainHarvestArea20211116', 
         'GrainHarvestArea20211117', 'GrainHarvestArea20211118', 'GrainHarvestArea20211119', 'GrainHarvestArea20211120', 
         'GrainHarvestArea20211121', 'GrainHarvestArea20211122', 'GrainHarvestArea20211123', 'GrainHarvestArea20211124', 
         'GrainHarvestArea20211125', 'GrainHarvestArea20211126', 'GrainHarvestArea20211127', 'GrainHarvestArea20211128']
print(len(list_28_11_21))
# Out:
# 126

# %%
df1.head()
# Out:
#    CityId CityNameTr  DistrictId DistrictNameTr PlaceName  GrainNoHarvestArea  \
# 0       1      ADANA          51        KARATAŞ     Adalı                 0.0
# 1       1      ADANA          51        KARATAŞ     Akdam                 0.0
# 2       1      ADANA          51        KARATAŞ     Bahçe                 0.0
# 3       1      ADANA          51        KARATAŞ    Bebeli                 0.0
# 4       1      ADANA          51        KARATAŞ    Beyköy                 0.0
#
#    GrainHarvestArea20210801  GrainHarvestArea20210802  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    GrainHarvestArea20210803  GrainHarvestArea20210804  ...  \
# 0                       NaN                       NaN  ...
# ...

# %%
df1['PlaceName'].isnull().value_counts()
# Out:
# False    20676
# True       543
# Name: PlaceName, dtype: int64

# %%
df1['PlaceName'].isnull().sum()
# Out:
# 543

# %%
df2 = df1

# %%
df2['list_27_09_21 sum']=df1.iloc[:,7:65].sum(axis=1)

# %%
df2['list_10_10_21 sum']=df1.iloc[:,7:78].sum(axis=1)

# %%
df2['list_17_10_21 sum']=df1.iloc[:,7:85].sum(axis=1)

# %%
df2['list_24_10_21 sum']=df1.iloc[:,7:92].sum(axis=1)

# %%
df2['list_30_10_21 sum']=df1.iloc[:,7:98].sum(axis=1)

# %%
df2['list_07_11_21 sum']=df1.iloc[:,7:106].sum(axis=1)

# %%
df2['list_14_11_21 sum']=df1.iloc[:,7:113].sum(axis=1)

# %%
df2['list_21_11_21 sum']=df1.iloc[:,7:120].sum(axis=1)

# %%
df2['list_28_11_21 sum']=df1.iloc[:,5:127].sum(axis=1)

# %%
df2['1. Urun Danelik Misir']=df1.iloc[:,7:128].sum(axis=1)

# %%
df2.head()
# Out:
#    CityId CityNameTr  DistrictId DistrictNameTr PlaceName  GrainNoHarvestArea  \
# 0       1      ADANA          51        KARATAŞ     Adalı                 0.0
# 1       1      ADANA          51        KARATAŞ     Akdam                 0.0
# 2       1      ADANA          51        KARATAŞ     Bahçe                 0.0
# 3       1      ADANA          51        KARATAŞ    Bebeli                 0.0
# 4       1      ADANA          51        KARATAŞ    Beyköy                 0.0
#
#    GrainHarvestArea20210801  GrainHarvestArea20210802  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    GrainHarvestArea20210803  GrainHarvestArea20210804  ...  list_27_09_21 sum  \
# 0                       NaN                       NaN  ...         164.472931
# ...

# %%
for i in df.columns:
    if i == "GrainHarvestArea20211231":
        df2["Bulut Engeli"] = df2[i]

# %%
for i in df.columns:
    if i == "GrainHarvestArea20220101":
        df2["Yakinda Hasat Yok"] = df2[i]

# %%
df5 = df2.drop(['GrainHarvestArea20210801', 'GrainHarvestArea20210802', 'GrainHarvestArea20210803', 'GrainHarvestArea20210804', 
         'GrainHarvestArea20210805', 'GrainHarvestArea20210806', 'GrainHarvestArea20210807', 'GrainHarvestArea20210808', 
         'GrainHarvestArea20210809', 'GrainHarvestArea20210810', 'GrainHarvestArea20210811', 'GrainHarvestArea20210812', 
         'GrainHarvestArea20210813', 'GrainHarvestArea20210814', 'GrainHarvestArea20210815', 'GrainHarvestArea20210816', 
         'GrainHarvestArea20210817', 'GrainHarvestArea20210818', 'GrainHarvestArea20210819', 'GrainHarvestArea20210820', 
         'GrainHarvestArea20210821', 'GrainHarvestArea20210822', 'GrainHarvestArea20210823', 'GrainHarvestArea20210824', 
         'GrainHarvestArea20210825', 'GrainHarvestArea20210826', 'GrainHarvestArea20210827', 'GrainHarvestArea20210828', 
         'GrainHarvestArea20210829', 'GrainHarvestArea20210830', 'GrainHarvestArea20210831', 'GrainHarvestArea20210901', 
         'GrainHarvestArea20210902', 'GrainHarvestArea20210903', 'GrainHarvestArea20210904', 'GrainHarvestArea20210905', 
         'GrainHarvestArea20210906', 'GrainHarvestArea20210907', 'GrainHarvestArea20210908', 'GrainHarvestArea20210909', 
         'GrainHarvestArea20210910', 'GrainHarvestArea20210911', 'GrainHarvestArea20210912', 'GrainHarvestArea20210913', 
         'GrainHarvestArea20210914', 'GrainHarvestArea20210915', 'GrainHarvestArea20210916', 'GrainHarvestArea20210917', 
         'GrainHarvestArea20210918', 'GrainHarvestArea20210919','GrainHarvestArea20210920', 'GrainHarvestArea20210921', 
         'GrainHarvestArea20210922', 'GrainHarvestArea20210923', 'GrainHarvestArea20210924', 'GrainHarvestArea20210925', 
         'GrainHarvestArea20210926', 'GrainHarvestArea20210927', 'GrainHarvestArea20210928', 'GrainHarvestArea20210929', 
         'GrainHarvestArea20210930', 'GrainHarvestArea20211001', 'GrainHarvestArea20211002', 'GrainHarvestArea20211003', 
         'GrainHarvestArea20211004', 'GrainHarvestArea20211005', 'GrainHarvestArea20211006', 'GrainHarvestArea20211007', 
         'GrainHarvestArea20211008', 'GrainHarvestArea20211009', 'GrainHarvestArea20211010', 'GrainHarvestArea20211011', 
         'GrainHarvestArea20211012', 'GrainHarvestArea20211013', 'GrainHarvestArea20211014', 'GrainHarvestArea20211015', 
         'GrainHarvestArea20211016', 'GrainHarvestArea20211017', 'GrainHarvestArea20211018', 'GrainHarvestArea20211019', 
         'GrainHarvestArea20211020', 'GrainHarvestArea20211021', 'GrainHarvestArea20211022', 'GrainHarvestArea20211023', 
         'GrainHarvestArea20211024', 'GrainHarvestArea20211025', 'GrainHarvestArea20211026', 'GrainHarvestArea20211027', 
         'GrainHarvestArea20211028', 'GrainHarvestArea20211029', 'GrainHarvestArea20211030', 'GrainHarvestArea20211031', 
         'GrainHarvestArea20211101', 'GrainHarvestArea20211102', 'GrainHarvestArea20211103', 'GrainHarvestArea20211104', 
         'GrainHarvestArea20211105', 'GrainHarvestArea20211106', 'GrainHarvestArea20211107', 'GrainHarvestArea20211108', 
         'GrainHarvestArea20211109', 'GrainHarvestArea20211110', 'GrainHarvestArea20211111', 'GrainHarvestArea20211112', 
         'GrainHarvestArea20211113', 'GrainHarvestArea20211114', 'GrainHarvestArea20211115', 'GrainHarvestArea20211116', 
         'GrainHarvestArea20211117', 'GrainHarvestArea20211118', 'GrainHarvestArea20211119', 'GrainHarvestArea20211120', 
         'GrainHarvestArea20211121', 'GrainHarvestArea20211122', 'GrainHarvestArea20211123', 'GrainHarvestArea20211124', 
         'GrainHarvestArea20211125', 'GrainHarvestArea20211126', 'GrainHarvestArea20211127', 'GrainHarvestArea20211128', 
         'GrainHarvestArea20211129', 'GrainHarvestArea20211130', 'GrainHarvestArea20211231', 'GrainHarvestArea20220101'],1)
# Out:
# C:\Users\BERRIN~1.GOC\AppData\Local\Temp/ipykernel_5132/2274881033.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df5 = df2.drop(['GrainHarvestArea20210801', 'GrainHarvestArea20210802', 'GrainHarvestArea20210803', 'GrainHarvestArea20210804',

# %%
df5.columns
# Out:
# Index(['CityId', 'CityNameTr', 'DistrictId', 'DistrictNameTr', 'PlaceName',
#        'GrainNoHarvestArea', 'list_27_09_21 sum', 'list_10_10_21 sum',
#        'list_17_10_21 sum', 'list_24_10_21 sum', 'list_30_10_21 sum',
#        'list_07_11_21 sum', 'list_14_11_21 sum', 'list_21_11_21 sum',
#        'list_28_11_21 sum', '1. Urun Danelik Misir', 'Bulut Engeli',
#        'Yakinda Hasat Yok'],
#       dtype='object')

# %%
df.shape
# Out:
# (21219, 130)

# %%
df5.head()
# Out:
#    CityId CityNameTr  DistrictId DistrictNameTr PlaceName  GrainNoHarvestArea  \
# 0       1      ADANA          51        KARATAŞ     Adalı                 0.0
# 1       1      ADANA          51        KARATAŞ     Akdam                 0.0
# 2       1      ADANA          51        KARATAŞ     Bahçe                 0.0
# 3       1      ADANA          51        KARATAŞ    Bebeli                 0.0
# 4       1      ADANA          51        KARATAŞ    Beyköy                 0.0
#
#    list_27_09_21 sum  list_10_10_21 sum  list_17_10_21 sum  list_24_10_21 sum  \
# 0         164.472931         227.577592         235.272529         236.082671
# 1         201.487551         208.175632         208.447400         208.605837
# 2         196.738835         256.462410         262.517848         266.237562
# 3         111.629739         136.099997         138.012293         139.012008
# 4          88.747131          95.999783          99.787921         102.693857
#
# ...

# %%
df5.info()
###'PlaceName' have null value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21219 entries, 0 to 21218
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CityId                 21219 non-null  int64
#  1   CityNameTr             21219 non-null  object
#  2   DistrictId             21219 non-null  int64
#  3   DistrictNameTr         21219 non-null  object
#  4   PlaceName              20676 non-null  object
#  5   GrainNoHarvestArea     7078 non-null   float64
#  6   list_27_09_21 sum      21219 non-null  float64
#  7   list_10_10_21 sum      21219 non-null  float64
#  8   list_17_10_21 sum      21219 non-null  float64
#  9   list_24_10_21 sum      21219 non-null  float64
#  10  list_30_10_21 sum      21219 non-null  float64
#  11  list_07_11_21 sum      21219 non-null  float64
#  12  list_14_11_21 sum      21219 non-null  float64
#  13  list_21_11_21 sum      21219 non-null  float64
# ...

# %%
#27/09/21, 10/10/21, 17/10/21, 24/10/21, 30/10/21, 07/11/21, 14/11/21, 21/11/21, 28/11/21

# %%
df6 = df5

# %%
#df6.groupby(['DistrictNameTr'])['list_27_09_21 sum','list_10_10_21 sum','list_17_10_21 sum',
                                #'list_24_10_21 sum','list_30_10_21 sum','list_07_11_21 sum',
                                #'list_14_11_21 sum','list_21_11_21 sum','list_28_11_21 sum'].agg(['sum']).reset_index().head(82)

# %%
df6.groupby(['DistrictNameTr','CityId'])['list_27_09_21 sum','list_10_10_21 sum','list_17_10_21 sum',
                                'list_24_10_21 sum','list_30_10_21 sum','list_07_11_21 sum',
                                'list_14_11_21 sum','list_21_11_21 sum','list_28_11_21 sum'].agg(['sum']).reset_index().head(90)
# Out:
# C:\Users\BERRIN~1.GOC\AppData\Local\Temp/ipykernel_5132/2648690317.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df6.groupby(['DistrictNameTr','CityId'])['list_27_09_21 sum','list_10_10_21 sum','list_17_10_21 sum',
#    DistrictNameTr CityId list_27_09_21 sum list_10_10_21 sum  \
#                                        sum               sum
# 0        19 MAYIS     55          2.018063          2.419231
# 1           ABANA     37          0.000000          0.000000
# 2          ACIGÖL     50         96.655297        246.989481
# 3        ACIPAYAM     20        378.357845        639.390923
# 4          ADAKLI     12          3.243051          3.281794
# ..            ...    ...               ...               ...
# 85        AĞLASUN     15          0.534108          0.856573
# 86           AĞLI     37          7.096870          7.542917
# ...

# %%
df7 = df5

# %%
df7.groupby(['DistrictNameTr','PlaceName'])['list_27_09_21 sum','list_10_10_21 sum','list_17_10_21 sum',
                                'list_24_10_21 sum','list_30_10_21 sum','list_07_11_21 sum',
                                'list_14_11_21 sum','list_21_11_21 sum','list_28_11_21 sum'].agg(['sum']).reset_index().head(99)
# Out:
# C:\Users\BERRIN~1.GOC\AppData\Local\Temp/ipykernel_5132/685552940.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df7.groupby(['DistrictNameTr','PlaceName'])['list_27_09_21 sum','list_10_10_21 sum','list_17_10_21 sum',
#    DistrictNameTr     PlaceName list_27_09_21 sum list_10_10_21 sum  \
#                                               sum               sum
# 0        19 MAYIS  Bahçelievler          0.000000          0.000000
# 1        19 MAYIS       Ballıca          0.127585          0.127585
# 2        19 MAYIS    Cumhuriyet          0.044335          0.044335
# 3        19 MAYIS         Engiz          0.022584          0.082881
# 4        19 MAYIS      Esentepe          0.082359          0.082359
# ..            ...           ...               ...               ...
# 94      ADAPAZARI  Ekizcemüslüm          4.013273         12.144065
# ...

# %%
df7.groupby(['DistrictNameTr','PlaceName', dropna == False])['list_27_09_21 sum','list_10_10_21 sum','list_17_10_21 sum',
                                'list_24_10_21 sum','list_30_10_21 sum','list_07_11_21 sum',
                                'list_14_11_21 sum','list_21_11_21 sum','list_28_11_21 sum'].agg(['sum']).reset_index().isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\BERRIN~1.GOC\AppData\Local\Temp/ipykernel_5132/1725234663.py in <module>
# ----> 1 df7.groupby(['DistrictNameTr','PlaceName', dropna == False])['list_27_09_21 sum','list_10_10_21 sum','list_17_10_21 sum',
#       2                                 'list_24_10_21 sum','list_30_10_21 sum','list_07_11_21 sum',
#       3                                 'list_14_11_21 sum','list_21_11_21 sum','list_28_11_21 sum'].agg(['sum']).reset_index().isnull().sum()
#
# NameError: name 'dropna' is not defined

# %%
df9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   (DistrictNameTr, )        8 non-null      object
#  1   (PlaceName, )             8 non-null      object
#  2   (list_27_09_21 sum, sum)  8 non-null      float64
#  3   (list_10_10_21 sum, sum)  8 non-null      float64
#  4   (list_17_10_21 sum, sum)  8 non-null      float64
#  5   (list_24_10_21 sum, sum)  8 non-null      float64
#  6   (list_30_10_21 sum, sum)  8 non-null      float64
#  7   (list_07_11_21 sum, sum)  8 non-null      float64
#  8   (list_14_11_21 sum, sum)  8 non-null      float64
#  9   (list_21_11_21 sum, sum)  8 non-null      float64
#  10  (list_28_11_21 sum, sum)  8 non-null      float64
# dtypes: float64(9), object(2)
# memory usage: 832.0+ bytes

# %%
df6.groupby(['DistrictNameTr','CityId'])['list_27_09_21 sum','list_10_10_21 sum','list_17_10_21 sum',
                                'list_24_10_21 sum','list_30_10_21 sum','list_07_11_21 sum',
                                'list_14_11_21 sum','list_21_11_21 sum','list_28_11_21 sum']
# Out:
# C:\Users\BERRIN~1.GOC\AppData\Local\Temp/ipykernel_5132/3435303210.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df6.groupby(['DistrictNameTr','CityId'])['list_27_09_21 sum','list_10_10_21 sum','list_17_10_21 sum',

# %%
df6['CityNameTr'=='ADANA'].value_counts()

# %%
df3['CityNameTr'].unique()

# %%
df3['DistrictNameTr'].value_counts()

# %%
x = df3.groupby("CityNameTr")["DistrictNameTr"].count()
x

# %%
df.groupby(["state", "gender"])["last_name"].count()

# %%
cars.rename(
    inplace=True,
    columns={
        "curb-weight": "curb_weight",
        'engine-size': 'engine_size',
        'wheel-base': 'wheel_base'
    })
